# %%
import cv2
import imutils
import math 

#import the library opencv
import cv2
#globbing utility.
import glob
#select the path
path = ""
for file in glob.glob(path):
print(file)
a= cv2.imread(file)
print(a)
# %%%%%%%%%%%%%%%%%%%%%
#conversion numpy array into rgb image to show
c = cv2.cvtColor(a, cv2.COLOR_BGR2RGB)
cv2.imshow('Color image', c)
#wait for 1 second
k = cv2.waitKey(1000)
#destroy the window
cv2.destroyAllWindows()

data = pd.read_csv('.json')     # reading the csv file
data.head()      # printing first five rows of the file

# hello word
